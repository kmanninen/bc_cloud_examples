# %%
# %matplotlib inline

# %% [markdown]
# # CenterNet (AkidaNet18)/PASCAL-VOC detection example
#
# This example demonstrates Akida's object detection capabilities using the CenterNet (AkidaNet18) architecture.

# %% [markdown]
# ### 1. Import model
#
# The model used for this demonstration can be found at the [Akida 2.0 Model Zoo](https://doc.brainchipinc.com/model_zoo_performance.html#id4). It has been pre-downloaded and converted to Akida here for efficiency.

# %%
from akida import Model

model_akida = Model("models/centernet_akidanet18_voc_384_i8_w8_a8.fbz")
model_akida.summary()
# Out:
#                  Model Summary
# ________________________________________________
# Input shape    Output shape  Sequences  Layers
# ================================================
# [384, 384, 3]  [96, 96, 24]  1          41
# ________________________________________________
#
# _________________________________________________________________________________________
# Layer (type)                                            Output shape   Kernel shape
#
# ======================== SW/convnext_stem-dequantizer (Software) ========================
#
# convnext_stem (InputConv2D)                             [96, 96, 64]   (4, 4, 3, 64)
# _________________________________________________________________________________________
# stage_0/conv_0 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)
# _________________________________________________________________________________________
# stage_0/conv_1 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)
# _________________________________________________________________________________________
# stage_0/conv_2 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)
# _________________________________________________________________________________________
# stage_0/conv_3 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)
# _________________________________________________________________________________________
# stage_1/conv_0 (Conv2D)                                 [48, 48, 128]  (3, 3, 64, 128)
# _________________________________________________________________________________________
# stage_1/conv_1 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)
# _________________________________________________________________________________________
# stage_1/conv_2 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)
# _________________________________________________________________________________________
# stage_1/conv_3 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)
# _________________________________________________________________________________________
# dw_stage_2/conv_0 (DepthwiseConv2D)                     [24, 24, 128]  (3, 3, 128, 1)
# _________________________________________________________________________________________
# pw_stage_2/conv_0 (Conv2D)                              [24, 24, 256]  (1, 1, 128, 256)
# _________________________________________________________________________________________
# dw_stage_2/conv_1 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)
# _________________________________________________________________________________________
# pw_stage_2/conv_1 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)
# _________________________________________________________________________________________
# dw_stage_2/conv_2 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)
# _________________________________________________________________________________________
# pw_stage_2/conv_2 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)
# _________________________________________________________________________________________
# dw_stage_2/conv_3 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)
# _________________________________________________________________________________________
# pw_stage_2/conv_3 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)
# _________________________________________________________________________________________
# dw_stage_3/conv_0 (DepthwiseConv2D)                     [12, 12, 256]  (3, 3, 256, 1)
# _________________________________________________________________________________________
# pw_stage_3/conv_0 (Conv2D)                              [12, 12, 512]  (1, 1, 256, 512)
# _________________________________________________________________________________________
# dw_stage_3/conv_1 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)
# _________________________________________________________________________________________
# pw_stage_3/conv_1 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)
# _________________________________________________________________________________________
# dw_stage_3/conv_2 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)
# _________________________________________________________________________________________
# pw_stage_3/conv_2 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)
# _________________________________________________________________________________________
# dw_stage_3/conv_3 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)
# _________________________________________________________________________________________
# pw_stage_3/conv_3 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)
# _________________________________________________________________________________________
# dw_neck_sepconv_0 (DepthwiseConv2D)                     [12, 12, 512]  (5, 5, 512, 1)
# _________________________________________________________________________________________
# pw_neck_sepconv_0 (Conv2D)                              [12, 12, 256]  (1, 1, 512, 256)
# _________________________________________________________________________________________
# dw_neck_transpose_sepconv_0 (DepthwiseConv2DTranspose)  [24, 24, 256]  (4, 4, 256, 1)
# _________________________________________________________________________________________
# pw_neck_transpose_sepconv_0 (Conv2D)                    [24, 24, 256]  (1, 1, 256, 256)
# _________________________________________________________________________________________
# neck_add_0 (Add)                                        [24, 24, 256]  N/A
# _________________________________________________________________________________________
# dw_neck_sepconv_1 (DepthwiseConv2D)                     [24, 24, 256]  (5, 5, 256, 1)
# _________________________________________________________________________________________
# pw_neck_sepconv_1 (Conv2D)                              [24, 24, 128]  (1, 1, 256, 128)
# _________________________________________________________________________________________
# dw_neck_transpose_sepconv_1 (DepthwiseConv2DTranspose)  [48, 48, 128]  (4, 4, 128, 1)
# _________________________________________________________________________________________
# pw_neck_transpose_sepconv_1 (Conv2D)                    [48, 48, 128]  (1, 1, 128, 128)
# _________________________________________________________________________________________
# neck_add_1 (Add)                                        [48, 48, 128]  N/A
# _________________________________________________________________________________________
# neck_conv_2 (Conv2D)                                    [48, 48, 64]   (3, 3, 128, 64)
# _________________________________________________________________________________________
# neck_transpose_conv_2 (Conv2DTranspose)                 [96, 96, 64]   (4, 4, 64, 64)
# _________________________________________________________________________________________
# neck_add_2 (Add)                                        [96, 96, 64]   N/A
# _________________________________________________________________________________________
# head_conv_1 (Conv2D)                                    [96, 96, 192]  (3, 3, 64, 192)
# _________________________________________________________________________________________
# voc_classifier (Conv2D)                                 [96, 96, 24]   (1, 1, 192, 24)
# _________________________________________________________________________________________
# dequantizer (Dequantizer)                               [96, 96, 24]   N/A
# _________________________________________________________________________________________

# %% [markdown]
# ### 2. Map the model onto the FPGA
#
# For more details on this flow, please see: [Model Hardware Mapping](https://doc.brainchipinc.com/user_guide/akida.html#model-hardware-mapping)

# %%
import akida
from cnn2snn import set_akida_version, AkidaVersion
# Instantiate akida model
with set_akida_version(AkidaVersion.v2):
    devices = akida.devices()
    if len(devices) > 0:
        print(f'Available devices: {[dev.desc for dev in devices]}')
        device = devices[0]
        print(device.version)
        try:
            model_akida.map(device)
            print(f"Mapping to Akida device {device.desc}.")
        except Exception as e:
            print("Model not compatible with FPGA. Running on CPU.")
    else:
        print("No Akida devices found, running on CPU.")
# Out:
# 2025-08-21 15:08:50.548029: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-21 15:08:50.570145: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-21 15:08:50.570165: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-21 15:08:50.570757: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-21 15:08:50.574342: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-21 15:08:51.030611: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/guest/.conda/envs/akida_env/lib/python3.11/site-packages/onnxscript/converter.py:816: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# Available devices: ['fpga-1691']
# BC.A2.001.000
# Mapping to Akida device fpga-1691.

# %% [markdown]
# ### Model Summary After Mapping

# %%
model_akida.summary()
# Out:
#                                       Model Summary
# _________________________________________________________________________________________
# Input shape    Output shape  Sequences  Layers  NPs  Skip DMAs  External Memory (Bytes)
# =========================================================================================
# [384, 384, 3]  [96, 96, 24]  3          41      36   0          0
# _________________________________________________________________________________________
#
# _________________________
# Component (type)  Count
# =========================
# HRC               1
# _________________________
# CNP1              36
# _________________________
#
# _____________________________________________________________________________________________________
# Layer (type)                                            Output shape   Kernel shape      Components
#
# ================== HW/convnext_stem-stage_0/conv_1 (Hardware) - size: 911380 bytes ==================
#
# convnext_stem (InputConv2D)                             [96, 96, 64]   (4, 4, 3, 64)     1 HRC
# _____________________________________________________________________________________________________
# stage_0/conv_0 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)    12 CNP1
# _____________________________________________________________________________________________________
# stage_0/conv_1 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)    12 CNP1
#
# ========================= HW/stage_0/conv_2 (Hardware) - size: 453220 bytes =========================
#
# stage_0/conv_2 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)    12 CNP1
#
# ============================== SW/stage_0/conv_3-dequantizer (Software) =============================
#
# stage_0/conv_3 (Conv2D)                                 [96, 96, 64]   (3, 3, 64, 64)    N/A
# _____________________________________________________________________________________________________
# stage_1/conv_0 (Conv2D)                                 [48, 48, 128]  (3, 3, 64, 128)   N/A
# _____________________________________________________________________________________________________
# stage_1/conv_1 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)  N/A
# _____________________________________________________________________________________________________
# stage_1/conv_2 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)  N/A
# _____________________________________________________________________________________________________
# stage_1/conv_3 (Conv2D)                                 [48, 48, 128]  (3, 3, 128, 128)  N/A
# _____________________________________________________________________________________________________
# dw_stage_2/conv_0 (DepthwiseConv2D)                     [24, 24, 128]  (3, 3, 128, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_2/conv_0 (Conv2D)                              [24, 24, 256]  (1, 1, 128, 256)  N/A
# _____________________________________________________________________________________________________
# dw_stage_2/conv_1 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_2/conv_1 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)  N/A
# _____________________________________________________________________________________________________
# dw_stage_2/conv_2 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_2/conv_2 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)  N/A
# _____________________________________________________________________________________________________
# dw_stage_2/conv_3 (DepthwiseConv2D)                     [24, 24, 256]  (3, 3, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_2/conv_3 (Conv2D)                              [24, 24, 256]  (1, 1, 256, 256)  N/A
# _____________________________________________________________________________________________________
# dw_stage_3/conv_0 (DepthwiseConv2D)                     [12, 12, 256]  (3, 3, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_3/conv_0 (Conv2D)                              [12, 12, 512]  (1, 1, 256, 512)  N/A
# _____________________________________________________________________________________________________
# dw_stage_3/conv_1 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_3/conv_1 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)  N/A
# _____________________________________________________________________________________________________
# dw_stage_3/conv_2 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_3/conv_2 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)  N/A
# _____________________________________________________________________________________________________
# dw_stage_3/conv_3 (DepthwiseConv2D)                     [12, 12, 512]  (3, 3, 512, 1)    N/A
# _____________________________________________________________________________________________________
# pw_stage_3/conv_3 (Conv2D)                              [12, 12, 512]  (1, 1, 512, 512)  N/A
# _____________________________________________________________________________________________________
# dw_neck_sepconv_0 (DepthwiseConv2D)                     [12, 12, 512]  (5, 5, 512, 1)    N/A
# _____________________________________________________________________________________________________
# pw_neck_sepconv_0 (Conv2D)                              [12, 12, 256]  (1, 1, 512, 256)  N/A
# _____________________________________________________________________________________________________
# dw_neck_transpose_sepconv_0 (DepthwiseConv2DTranspose)  [24, 24, 256]  (4, 4, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_neck_transpose_sepconv_0 (Conv2D)                    [24, 24, 256]  (1, 1, 256, 256)  N/A
# _____________________________________________________________________________________________________
# neck_add_0 (Add)                                        [24, 24, 256]  N/A               N/A
# _____________________________________________________________________________________________________
# dw_neck_sepconv_1 (DepthwiseConv2D)                     [24, 24, 256]  (5, 5, 256, 1)    N/A
# _____________________________________________________________________________________________________
# pw_neck_sepconv_1 (Conv2D)                              [24, 24, 128]  (1, 1, 256, 128)  N/A
# _____________________________________________________________________________________________________
# dw_neck_transpose_sepconv_1 (DepthwiseConv2DTranspose)  [48, 48, 128]  (4, 4, 128, 1)    N/A
# _____________________________________________________________________________________________________
# pw_neck_transpose_sepconv_1 (Conv2D)                    [48, 48, 128]  (1, 1, 128, 128)  N/A
# _____________________________________________________________________________________________________
# neck_add_1 (Add)                                        [48, 48, 128]  N/A               N/A
# _____________________________________________________________________________________________________
# neck_conv_2 (Conv2D)                                    [48, 48, 64]   (3, 3, 128, 64)   N/A
# _____________________________________________________________________________________________________
# neck_transpose_conv_2 (Conv2DTranspose)                 [96, 96, 64]   (4, 4, 64, 64)    N/A
# _____________________________________________________________________________________________________
# neck_add_2 (Add)                                        [96, 96, 64]   N/A               N/A
# _____________________________________________________________________________________________________
# head_conv_1 (Conv2D)                                    [96, 96, 192]  (3, 3, 64, 192)   N/A
# _____________________________________________________________________________________________________
# voc_classifier (Conv2D)                                 [96, 96, 24]   (1, 1, 192, 24)   N/A
# _____________________________________________________________________________________________________
# dequantizer (Dequantizer)                               [96, 96, 24]   N/A               N/A
# _____________________________________________________________________________________________________

# %% [markdown]
# ### 3 Run inference on a image
#
# Here, an image is preprocessed and evaluated through the Akida model. Bounding boxes for detected objects are returned and superimposed on the image using the anchors.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from akida_models.detection.processing import preprocess_image
from akida_models.centernet.centernet_processing import decode_output

import cv2

labels = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
          'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse',
          'motorbike', 'person', 'pottedplant', 'sheep', 'sofa',
          'train', 'tvmonitor']

input_shape = model_akida.layers[0].input_dims

# Load the image
raw_image = cv2.imread("img/train.jpg")

# Keep the original image size for later bounding boxes rescaling
raw_height, raw_width, _ = raw_image.shape

# Pre-process the image
image = preprocess_image(raw_image, input_shape)
input_image = image[np.newaxis, :].astype(np.uint8)

output_img = np.copy(raw_image)

# Call evaluate on the image
pots = model_akida.predict(input_image)[0]

bounding_boxes = decode_output(pots,
                        20,
                        obj_threshold=0.4,
                        max_detections=100,
                        kernel=5)
            
for box in bounding_boxes:
        output_img = cv2.rectangle( output_img, 
                    (int(box.x1 * raw_width), int(box.y1 * raw_height)),
                    (int(box.x2 * raw_width), int(box.y2 * raw_height)),
                    color=(0, 255, 0),
                    thickness=2)
        output_img = cv2.putText(output_img,
                    f'{labels[box.get_label()]}',
                    (int(box.x1 * raw_width), int(box.y1 * raw_height - 10)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (255, 0, 0),
                    1)

fig = plt.figure(num='VOC detection by Akida')
ax = fig.subplots(1)
img_plot = ax.imshow(np.zeros(output_img.shape, dtype=np.uint8))
img_plot.set_data(output_img)

plt.axis('off')
plt.show()

# %% [markdown]
# ### 4 Model Statistics
#
# The advantage of running on a FPGA is the ability to accurately calculate performance, power and area metrics for a given model and process node.
#
# Here are example calculations for the CenterNet model that was tested above.

# %% [markdown]
# #### Performance
#
# This Akida 6-Node FPGA is running at __25 MHz__. Based on that knowledge, we need to know the frames per second on the FPGA. The `akida.Model.statistics.fps` will return this value.

# %%
akida_fpga_mhz = 25  # MHz
fps = model_akida.statistics.fps
print(f"FPS @ {akida_fpga_mhz} MHz: {fps}")
# Out:
# FPS @ 25 MHz: 1.1918951132300357

# %% [markdown]
# To estimate frames per second at a different frequency use the calculation:
#
# $$ \frac{\text{estimated\_fps}}{\text{estimated\_mhz}} = \frac{\text{fps}}{\text{akida\_fpga\_mhz}}$$
#
# $$\text{estimated\_fps} = \frac{\text{fps} \times \text{estimated\_mhz}}{\text{akida\_fpga\_mhz}} $$

# %%
estimated_mhz = 400  # Change this to your desired frequency
estimated_fps = (fps * estimated_mhz) / akida_fpga_mhz
print(f"Estimated FPS @ {estimated_mhz} MHz: {estimated_fps}")
# Out:
# Estimated FPS @ 400 MHz: 19.07032181168057

# %% [markdown]
# #### Power
#
# Estimating power consumption of a model involves understanding the architecture and size of the model (e.g. # parameters, types of layer operations, etc) as well as a target process node (e.g. TSMC 28nm, Global Foundry 22nm, etc) and target chip frequency (e.g. 400 MHz, 1 GHz, etc).
#
# Brainchip's Solution Architects have access to up to date calculations for the Akida 2.0 Register-transfer-level (RTL) and can perform estimates for your particular model. Contact your BrainChip representative when you have a model ready for estimating.
#
# We will use BrainChip's calculations for the CenterNet (AkidaNet 18 backbone, 2.4M parameters, 384x384 resolution) here to illustrate power consumption.
#
# Consider the following formula:
#
# $$ \text{Total Power (W)} = \frac{\text{Energy per Inference (J)}}{\text{Time per Inference (s)}} \times \text{Frames per Second} $$
#
# and CenterNet (AkidaNet 18 backbone, 2.4M parameters, 384x384 resolution) Energy per inference = 38.46 mJ while running 400 MHz.
#
# The calculation for Total Power is:

# %%
centernet_energy_per_infernence_mJ = 38.46  # Change this to your measured energy per inference in mJ

total_power_mw = (centernet_energy_per_infernence_mJ * estimated_fps) / 1000  # Convert mJ to mW

print(f"Estimated IP Total Power: {total_power_mw:.2f} mW at {estimated_mhz} MHz")
# Out:
# Estimated IP Total Power: 0.73 mW at 400 MHz

# %% [markdown]
# #### Area
#
# Similar to power, estimating the area size required for a chip to run a model involves understanding the architecture and size of the model (e.g. # parameters, types of layer operations, etc) as well as a target process node (e.g. TSMC 28nm, Global Foundry 22nm, etc) and the ability to leverage RTL options such Hardware Partial Reconfiguration.
#
# A model that executes successfully on the FPGA is capable of receiving accurate sizing estimations. BrainChip's Solution Architects can assist with these calculations.
#
# For this CenterNet (AkidaNet18) example, BrainChip has calculated the area for Global Foundry 22nm:
#
# | Specification       | Value  |
# |---------------------|--------|
# | Logic Gate Count (M)| 193.86 |
# | Memory Size (KB)    | 43042  |
# | Logic Area (mm²)    | 36.77  |
# | Memory Area (mm²)   | 65.53  |
# | Total Area (mm²)    | 102.3  |

# %% [markdown]
# ### Note: Once you’ve finished running the notebook, ***"Uncomment and run the cell below"*** to release the device and free it up for further experiments.

# %%
# import os
# os._exit(00)

# %% [markdown]
# #### You can also use this button to reset your kernel
#
# ![image.png](attachment:0611b1d1-afe0-43f4-9f21-abb772e7d0fd.png)
